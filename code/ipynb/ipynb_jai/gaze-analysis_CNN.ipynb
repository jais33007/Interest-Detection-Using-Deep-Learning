# %%
import glob
import pandas as pd
import numpy as np

import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Reshape, GlobalAveragePooling1D
from keras.layers import Conv1D, MaxPooling1D
from keras.utils import np_utils
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, accuracy_score

from keras.layers import LSTM, Dense, Conv1D, TimeDistributed, Flatten, Activation, Dropout, Bidirectional,concatenate
from keras.callbacks import History, TensorBoard, Callback
import keras.initializers as KI
from keras.layers import BatchNormalization
from sklearn.metrics import f1_score, precision_score, recall_score

from sklearn.preprocessing import StandardScaler
import scipy.stats as stats
import warnings
warnings.filterwarnings("ignore")

from tqdm.keras import TqdmCallback

# %%
#merge the gaze labelled data for each participant and document
gaze_path = "../../data/working/gaze_labelled/"
gaze_list = [pd.read_csv(data, index_col=0) for data in sorted(glob.glob(gaze_path + "/*/*"))]
gaze_data = pd.concat(gaze_list, ignore_index=True, sort=False)

# %%
tf.config.experimental.set_visible_devices([], 'GPU')

# %%
gaze_data.columns
# features = ['left_gaze_x', 'left_gaze_y',
#        'left_position_x', 'left_position_y', 'left_position_z', 'left_pupil',
#        'right_gaze_x', 'right_gaze_y', 'right_position_x', 'right_position_y',
#        'right_position_z', 'right_pupil','understand']

features = ['left_gaze_x', 'left_gaze_y', 'right_gaze_x', 'right_gaze_y','understand','interest']

participants = gaze_data.participant.unique()

# %%
gaze_data['interest'] = gaze_data['interest'].replace([1,2,3,4], [0,1,2,3])
gaze_data['understand'] = gaze_data['understand'].replace([1,2,3,4], [0,1,2,3])
#gaze_data['bin_interest'] = gaze_data['interest'].replace([0,1,2,3])

# %%
def normalize(dataset):
    mu = np.mean(dataset, axis=0)
    sigma = np.std(dataset, axis=0)
    return (dataset - mu)/sigma

def get_frames(df, frame_size, step_size, label_name):

    N_FEATURES = len(features) - 1

    frames = []
    labels = []
    for i in range(0, len(df) - frame_size, step_size):
        for column in df.columns:
            if column!=label_name:
                column = df[column].values[i: i + frame_size]
                frames.append([column])
        else:
            
        # Retrieve the most often used label in this segment
            label = stats.mode(df[label_name][i: i + frame_size])[0][0]
            labels.append(label)

    # Bring the segments into a better shape
    frames = np.asarray(frames).reshape(-1, frame_size, N_FEATURES)
    labels = np.asarray(labels)

    return frames, labels

# %%
samp_freq = 60
frame_size = samp_freq*30 
step_size = samp_freq*15 

def prepare_data(data, fold):
  
    df_val = data[data['participant'] == participants[fold]]
    df_train = data[data['participant'] != participants[fold]]

    # df_train.drop(['participant','document'], axis=1, inplace=True)
    # df_val.drop(['participant','document'], axis=1, inplace=True)

    df_train = df_train[features]
    df_val = df_val[features]
    
    for col in df_train.columns:
        
        if col != 'interest':        
            df_train[col] = normalize(df_train[col])
            df_val[col] = normalize(df_val[col])

    x_train, y_train = get_frames(df_train, frame_size, step_size, 'interest')
    num_time_periods, num_sensors = x_train.shape[1], x_train.shape[2]
    num_classes = 4
    print (x_train.shape, y_train.shape)

    input_shape = (num_time_periods * num_sensors)
    x_train = x_train.reshape(x_train.shape[0], input_shape)

    # x_train = x_train.astype("float32")
    # y_train = y_train.astype("float32")

    #y_train = np_utils.to_categorical(y_train, num_classes)
    print(y_train.shape)

    x_val, y_val = get_frames(df_val, frame_size, step_size, 'interest')

    num_time_periods1, num_sensors1 = x_val.shape[1], x_val.shape[2]

    input_shape1 = (num_time_periods1 * num_sensors1)
    x_val = x_val.reshape(x_val.shape[0], input_shape1)

    # x_val = x_val.astype("float32")
    # y_val = y_val.astype("float32")

    #y_val = np_utils.to_categorical(y_val, num_classes)

    return num_time_periods, num_sensors, x_train, x_val, y_train, y_val

# %%
# Hyper-parameters
BATCH_SIZE = 256
EPOCHS = 10

# %%
conf_matrix_list_of_arrays = []
scores = []
acc_per_fold = []
loss_per_fold = []
f1_per_fold = []
prec_per_fold = []
rec_per_fold = []

def build_model(num_time_periods, num_sensors, num_classes, input_shape):
  # 1D CNN neural network
    
    model = Sequential()
    model.add(Reshape((frame_size, num_sensors), input_shape=(input_shape,)))
    model.add(Conv1D(64, 5, activation='relu', input_shape=(frame_size, num_sensors)))
    model.add(Conv1D(32, 5, activation='relu'))
    model.add(MaxPooling1D(2))
    model.add(Conv1D(32, 10, activation='relu'))

    model.add(Conv1D(15, 3, activation='relu'))
    model.add(Dropout(0.2))

    model.add(Flatten())
    model.add(Dense(128, activation='relu'))

    model.add(Dense(num_classes, activation='softmax'))

    model.compile(loss='sparse_categorical_crossentropy',
                  optimizer='adam', metrics=['accuracy'])
    return model


def evaluate(num_time_periods, num_sensors,t_x, val_x, t_y, val_y, EPOCHS, BATCH_SIZE):
    
    input_shape = (num_time_periods * num_sensors)
    model = build_model(num_time_periods, num_sensors, 4, input_shape)
    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)

    history = model.fit(t_x, t_y, epochs=EPOCHS, batch_size=BATCH_SIZE, verbose=1, callbacks=[es], validation_split=0.3)
    scores = model.evaluate(val_x, val_y)
    print(f'Score : {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%')
    acc_per_fold.append(scores[1])
    loss_per_fold.append(scores[0])
    
    
    y_pred = np.argmax(model.predict(val_x), axis=-1)
    f1_per_fold.append(f1_score(val_y, y_pred, average='weighted'))
    prec_per_fold.append(precision_score(val_y, y_pred, average='weighted'))
    rec_per_fold.append(recall_score(val_y, y_pred, average='weighted'))
    print('F1 score : ', f1_score(val_y, y_pred, average='weighted'))


    cm = confusion_matrix(val_y, y_pred, labels=[0,1,2,3])
    print('Confusion Matrix : ')
    print(cm)
    
    #conf_matrix_list_of_arrays.append(cm)
    return history, scores, y_pred, acc_per_fold, f1_per_fold

def plot_cmx(labels, predicteds, binary=False):
    cmx = confusion_matrix(labels, predicteds)
    cmx = cmx.astype('float') / cmx.sum(axis=1)[:, np.newaxis]
    if binary:
        class_names = ['not-interested', 'interested']
    else:
        class_names = ['1','2','3','4']
    plt.figure(figsize=(8, 6))
    plt.title("mean accuracy: %.2f" % accuracy_score(labels, predicteds))
    sns.heatmap(cmx, annot=True, fmt=".0%",center=1, xticklabels=class_names, yticklabels=class_names)

    plt.ylabel('Predicted')
    plt.xlabel('Actual')
    plt.show()

# %%
model_history = [] 
cvscores = []
predicted = []
labels = []

for i in range(len(participants)):
    
    pred = []
    label = []
    print("Training with participant "+ participants[i] +" left out")
    num_time_periods, num_sensors, t_x, val_x, t_y, val_y = prepare_data(gaze_data, i)
    results, scores, preds, acc, f1 = evaluate(num_time_periods, num_sensors,t_x, val_x, t_y, val_y, EPOCHS, BATCH_SIZE)
    model_history.append(results)
    cvscores.append(scores[1] * 100)
    predicted.extend(preds)
    labels.extend(val_y) 
    print("Accuracy with participant " + participants[i] + ' as test :'+str(scores[1]*100))
    print("======="*12, end="\n\n\n")

#predicted = np.argmax(predicted, axis=1)
plot_cmx(labels, predicted)
print ('Average accuracy with all the participants')
# Out:
# Training with participant p01 left out
# (3076, 1800, 5) (3076,)
# (3076,)
# Epoch 1/10
# 9/9 [==============================] - 6s 579ms/step - loss: 0.8851 - accuracy: 0.6033 - val_loss: 0.5620 - val_accuracy: 0.7595
# Epoch 2/10
# 9/9 [==============================] - 5s 547ms/step - loss: 0.6729 - accuracy: 0.7264 - val_loss: 0.5408 - val_accuracy: 0.7551
# Epoch 3/10
# 9/9 [==============================] - 5s 542ms/step - loss: 0.6166 - accuracy: 0.7571 - val_loss: 0.7120 - val_accuracy: 0.6533
# Epoch 4/10
# 9/9 [==============================] - 5s 544ms/step - loss: 0.5604 - accuracy: 0.7687 - val_loss: 0.6896 - val_accuracy: 0.6717
# Epoch 5/10
# 9/9 [==============================] - 5s 544ms/step - loss: 0.4708 - accuracy: 0.8244 - val_loss: 0.6849 - val_accuracy: 0.6804
# Epoch 6/10
# 9/9 [==============================] - 5s 584ms/step - loss: 0.3884 - accuracy: 0.8439 - val_loss: 0.6547 - val_accuracy: 0.7324
# Epoch 7/10
# 9/9 [==============================] - 5s 566ms/step - loss: 0.3273 - accuracy: 0.8751 - val_loss: 0.9849 - val_accuracy: 0.6100
# Epoch 8/10
# 9/9 [==============================] - 5s 562ms/step - loss: 0.2617 - accuracy: 0.9015 - val_loss: 0.9209 - val_accuracy: 0.6446
# Epoch 9/10
# 9/9 [==============================] - 5s 558ms/step - loss: 0.1912 - accuracy: 0.9354 - val_loss: 1.1104 - val_accuracy: 0.6262
# Epoch 10/10
# 9/9 [==============================] - 5s 555ms/step - loss: 0.1368 - accuracy: 0.9573 - val_loss: 1.2573 - val_accuracy: 0.6121
# 7/7 [==============================] - 0s 20ms/step - loss: 1.3000 - accuracy: 0.5314
# Score : loss of 1.300048589706421; accuracy of 53.140097856521606%
# 7/7 [==============================] - 0s 23ms/step
# F1 score :  0.5310367327563499
# Confusion Matrix :
# [[40  0  1  0]
#  [43 51 52  0]
#  [ 0  1 19  0]
#  [ 0  0  0  0]]
# Accuracy with participant p01 as test :53.140097856521606
# ====================================================================================
#
#
# Training with participant p02 left out
# (2928, 1800, 5) (2928,)
# (2928,)
# Epoch 1/10
# 9/9 [==============================] - 6s 580ms/step - loss: 0.8923 - accuracy: 0.5847 - val_loss: 0.7317 - val_accuracy: 0.4949
# Epoch 2/10
# 9/9 [==============================] - 5s 540ms/step - loss: 0.7106 - accuracy: 0.6462 - val_loss: 0.5562 - val_accuracy: 0.7918
# Epoch 3/10
# 9/9 [==============================] - 5s 518ms/step - loss: 0.6377 - accuracy: 0.7252 - val_loss: 0.5929 - val_accuracy: 0.7440
# Epoch 4/10
# 9/9 [==============================] - 5s 529ms/step - loss: 0.6191 - accuracy: 0.7448 - val_loss: 0.6872 - val_accuracy: 0.6576
# Epoch 5/10
# 9/9 [==============================] - 5s 518ms/step - loss: 0.5319 - accuracy: 0.7755 - val_loss: 0.5327 - val_accuracy: 0.7918
# Epoch 6/10
# 9/9 [==============================] - 5s 522ms/step - loss: 0.5186 - accuracy: 0.7828 - val_loss: 0.6804 - val_accuracy: 0.6826
# Epoch 7/10
# 9/9 [==============================] - 5s 531ms/step - loss: 0.5390 - accuracy: 0.7818 - val_loss: 1.0649 - val_accuracy: 0.5336
# Epoch 8/10
# 9/9 [==============================] - 5s 527ms/step - loss: 0.5598 - accuracy: 0.7531 - val_loss: 1.0130 - val_accuracy: 0.5154
# Epoch 9/10
# 9/9 [==============================] - 5s 520ms/step - loss: 0.5374 - accuracy: 0.7862 - val_loss: 0.7750 - val_accuracy: 0.6712
# Epoch 10/10
# 9/9 [==============================] - 5s 533ms/step - loss: 0.5073 - accuracy: 0.8014 - val_loss: 0.6911 - val_accuracy: 0.7042
# 12/12 [==============================] - 0s 21ms/step - loss: 1.1507 - accuracy: 0.6208
# Score : loss of 1.1506725549697876; accuracy of 62.078648805618286%
# 12/12 [==============================] - 0s 21ms/step
# F1 score :  0.589583439478992
# Confusion Matrix :
# [[103   0   1   0]
#  [ 90  28   9   0]
#  [ 29   6  90   0]
#  [  0   0   0   0]]
# Accuracy with participant p02 as test :62.078648805618286
# ====================================================================================
#
#
# Training with participant p05 left out
# (3106, 1800, 5) (3106,)
# (3106,)
# Epoch 1/10
# 9/9 [==============================] - 6s 584ms/step - loss: 0.9347 - accuracy: 0.5929 - val_loss: 0.7310 - val_accuracy: 0.6094
# Epoch 2/10
# 9/9 [==============================] - 5s 577ms/step - loss: 0.6563 - accuracy: 0.7291 - val_loss: 0.5920 - val_accuracy: 0.6502
# Epoch 3/10
# 9/9 [==============================] - 5s 559ms/step - loss: 0.6177 - accuracy: 0.7539 - val_loss: 0.6575 - val_accuracy: 0.6288
# Epoch 4/10
# 9/9 [==============================] - 5s 559ms/step - loss: 0.5930 - accuracy: 0.7534 - val_loss: 0.5974 - val_accuracy: 0.6717
# Epoch 5/10
# 9/9 [==============================] - 5s 569ms/step - loss: 0.5604 - accuracy: 0.7677 - val_loss: 0.6225 - val_accuracy: 0.6652
# Epoch 6/10
# 9/9 [==============================] - 5s 563ms/step - loss: 0.5309 - accuracy: 0.7797 - val_loss: 0.6690 - val_accuracy: 0.6513
# Epoch 7/10
# 9/9 [==============================] - 5s 557ms/step - loss: 0.4785 - accuracy: 0.8068 - val_loss: 0.8146 - val_accuracy: 0.5805
# Epoch 8/10
# 9/9 [==============================] - 5s 571ms/step - loss: 0.4392 - accuracy: 0.8243 - val_loss: 0.6664 - val_accuracy: 0.6824
# Epoch 9/10
# 9/9 [==============================] - 5s 566ms/step - loss: 0.3680 - accuracy: 0.8546 - val_loss: 0.9219 - val_accuracy: 0.6041
# Epoch 10/10
# 9/9 [==============================] - 5s 564ms/step - loss: 0.3514 - accuracy: 0.8574 - val_loss: 0.7645 - val_accuracy: 0.7017
# 6/6 [==============================] - 0s 22ms/step - loss: 1.6274 - accuracy: 0.4888
# Score : loss of 1.6274245977401733; accuracy of 48.876404762268066%
# 6/6 [==============================] - 0s 19ms/step
# F1 score :  0.5413198453881799
# Confusion Matrix :
# [[54 11  4  0]
#  [10 27 66  0]
#  [ 0  0  6  0]
#  [ 0  0  0  0]]
# Accuracy with participant p05 as test :48.876404762268066
# ====================================================================================
#
#
# Training with participant p06 left out
# (3080, 1800, 5) (3080,)
# (3080,)
# Epoch 1/10
# 9/9 [==============================] - 6s 600ms/step - loss: 1.3076 - accuracy: 0.4504 - val_loss: 0.9692 - val_accuracy: 0.5368
# Epoch 2/10
# 9/9 [==============================] - 5s 556ms/step - loss: 0.7046 - accuracy: 0.7083 - val_loss: 0.7294 - val_accuracy: 0.5898
# Epoch 3/10
# 9/9 [==============================] - 5s 550ms/step - loss: 0.6397 - accuracy: 0.7180 - val_loss: 0.7216 - val_accuracy: 0.5866
# Epoch 4/10
# 9/9 [==============================] - 5s 568ms/step - loss: 0.6048 - accuracy: 0.7222 - val_loss: 0.7212 - val_accuracy: 0.5487
# Epoch 5/10
# 9/9 [==============================] - 5s 564ms/step - loss: 0.5704 - accuracy: 0.7412 - val_loss: 0.5872 - val_accuracy: 0.7165
# Epoch 6/10
# 9/9 [==============================] - 5s 565ms/step - loss: 0.5550 - accuracy: 0.7393 - val_loss: 0.7378 - val_accuracy: 0.5952
# Epoch 7/10
# 9/9 [==============================] - 5s 568ms/step - loss: 0.5390 - accuracy: 0.7574 - val_loss: 0.7385 - val_accuracy: 0.5747
# Epoch 8/10
# 9/9 [==============================] - 5s 559ms/step - loss: 0.5236 - accuracy: 0.7764 - val_loss: 0.7679 - val_accuracy: 0.6039
# Epoch 9/10
# 9/9 [==============================] - 5s 557ms/step - loss: 0.4909 - accuracy: 0.7811 - val_loss: 0.7777 - val_accuracy: 0.6255
# Epoch 10/10
# 9/9 [==============================] - 5s 576ms/step - loss: 0.4673 - accuracy: 0.7922 - val_loss: 0.6726 - val_accuracy: 0.6277
# 7/7 [==============================] - 0s 21ms/step - loss: 1.4022 - accuracy: 0.6078
# Score : loss of 1.402225136756897; accuracy of 60.784316062927246%
# 7/7 [==============================] - 0s 19ms/step
# F1 score :  0.6012266848996817
# Confusion Matrix :
# [[46  0  0  0]
#  [11 32  0  0]
#  [17 52 46  0]
#  [ 0  0  0  0]]
# Accuracy with participant p06 as test :60.784316062927246
# ====================================================================================
#
#
# Training with participant p07 left out
# (3075, 1800, 5) (3075,)
# (3075,)
# Epoch 1/10
# 9/9 [==============================] - 6s 583ms/step - loss: 0.9890 - accuracy: 0.5776 - val_loss: 0.5508 - val_accuracy: 0.7692
# Epoch 2/10
# 9/9 [==============================] - 5s 555ms/step - loss: 0.7454 - accuracy: 0.7045 - val_loss: 0.8070 - val_accuracy: 0.6241
# Epoch 3/10
# 9/9 [==============================] - 5s 570ms/step - loss: 0.6703 - accuracy: 0.7319 - val_loss: 0.6693 - val_accuracy: 0.6176
# Epoch 4/10
# 9/9 [==============================] - 5s 555ms/step - loss: 0.6154 - accuracy: 0.7407 - val_loss: 0.6377 - val_accuracy: 0.6468
# Epoch 5/10
# 9/9 [==============================] - 5s 587ms/step - loss: 0.5800 - accuracy: 0.7514 - val_loss: 0.7155 - val_accuracy: 0.6143
# Epoch 6/10
# 9/9 [==============================] - 5s 556ms/step - loss: 0.5242 - accuracy: 0.7793 - val_loss: 0.6714 - val_accuracy: 0.6381
# Epoch 7/10
# 9/9 [==============================] - 5s 563ms/step - loss: 0.4838 - accuracy: 0.8002 - val_loss: 0.7711 - val_accuracy: 0.6197
# Epoch 8/10
# 9/9 [==============================] - 5s 551ms/step - loss: 0.4093 - accuracy: 0.8336 - val_loss: 0.7742 - val_accuracy: 0.6100
# Epoch 9/10
# 9/9 [==============================] - 5s 551ms/step - loss: 0.3398 - accuracy: 0.8620 - val_loss: 0.9258 - val_accuracy: 0.6002
# Epoch 10/10
# 9/9 [==============================] - 5s 551ms/step - loss: 0.2753 - accuracy: 0.8899 - val_loss: 1.0891 - val_accuracy: 0.5948
# 7/7 [==============================] - 0s 21ms/step - loss: 1.3958 - accuracy: 0.6077
# Score : loss of 1.395811676979065; accuracy of 60.76555252075195%
# 7/7 [==============================] - 0s 21ms/step
# F1 score :  0.634083221988266
# Confusion Matrix :
# [[94 27 20  0]
#  [ 0  4 33  0]
#  [ 1  1 29  0]
#  [ 0  0  0  0]]
# Accuracy with participant p07 as test :60.76555252075195
# ====================================================================================
#
#
# Training with participant p08 left out
# (3060, 1800, 5) (3060,)
# (3060,)
# Epoch 1/10
# 9/9 [==============================] - 6s 579ms/step - loss: 1.3855 - accuracy: 0.4118 - val_loss: 0.7141 - val_accuracy: 0.7538
# Epoch 2/10
# 9/9 [==============================] - 5s 553ms/step - loss: 0.7576 - accuracy: 0.6573 - val_loss: 0.6165 - val_accuracy: 0.6220
# Epoch 3/10
# 9/9 [==============================] - 5s 557ms/step - loss: 0.6804 - accuracy: 0.7176 - val_loss: 0.7267 - val_accuracy: 0.6111
# Epoch 4/10
# 9/9 [==============================] - 6s 628ms/step - loss: 0.6544 - accuracy: 0.7162 - val_loss: 0.6824 - val_accuracy: 0.6187
# Epoch 5/10
# 9/9 [==============================] - 5s 565ms/step - loss: 0.6242 - accuracy: 0.7250 - val_loss: 0.6498 - val_accuracy: 0.6187
# Epoch 6/10
# 9/9 [==============================] - 6s 638ms/step - loss: 0.6013 - accuracy: 0.7442 - val_loss: 0.6581 - val_accuracy: 0.6166
# Epoch 7/10
# 9/9 [==============================] - 5s 555ms/step - loss: 0.5578 - accuracy: 0.7624 - val_loss: 0.6556 - val_accuracy: 0.6492
# Epoch 8/10
# 9/9 [==============================] - 5s 555ms/step - loss: 0.5166 - accuracy: 0.7834 - val_loss: 0.7707 - val_accuracy: 0.5806
# Epoch 9/10
# 9/9 [==============================] - 5s 556ms/step - loss: 0.4653 - accuracy: 0.8025 - val_loss: 0.7267 - val_accuracy: 0.6231
# Epoch 10/10
# 9/9 [==============================] - 5s 569ms/step - loss: 0.4109 - accuracy: 0.8375 - val_loss: 0.8225 - val_accuracy: 0.6133
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6799 - accuracy: 0.7723
# Score : loss of 0.6798614263534546; accuracy of 77.23214030265808%
# 7/7 [==============================] - 0s 21ms/step
# F1 score :  0.7866625816993464
# Confusion Matrix :
# [[76  8  8  0]
#  [11 13  3  0]
#  [ 1 20 84  0]
#  [ 0  0  0  0]]
# Accuracy with participant p08 as test :77.23214030265808
# ====================================================================================
#
#
# Training with participant p09 left out
# (2932, 1800, 5) (2932,)
# (2932,)
# Epoch 1/10
# 9/9 [==============================] - 6s 549ms/step - loss: 0.9906 - accuracy: 0.5112 - val_loss: 0.8483 - val_accuracy: 0.5966
# Epoch 2/10
# 9/9 [==============================] - 5s 524ms/step - loss: 0.7411 - accuracy: 0.6988 - val_loss: 0.6110 - val_accuracy: 0.8205
# Epoch 3/10
# 9/9 [==============================] - 5s 539ms/step - loss: 0.7568 - accuracy: 0.6574 - val_loss: 0.6417 - val_accuracy: 0.6193
# Epoch 4/10
# 9/9 [==============================] - 5s 522ms/step - loss: 0.7011 - accuracy: 0.6886 - val_loss: 0.7155 - val_accuracy: 0.5500
# Epoch 5/10
# 9/9 [==============================] - 5s 521ms/step - loss: 0.6639 - accuracy: 0.7100 - val_loss: 0.6279 - val_accuracy: 0.6409
# Epoch 6/10
# 9/9 [==============================] - 5s 524ms/step - loss: 0.6483 - accuracy: 0.7159 - val_loss: 0.7228 - val_accuracy: 0.5909
# Epoch 7/10
# 9/9 [==============================] - 5s 532ms/step - loss: 0.5948 - accuracy: 0.7471 - val_loss: 0.6731 - val_accuracy: 0.6318
# Epoch 8/10
# 9/9 [==============================] - 5s 525ms/step - loss: 0.5476 - accuracy: 0.7651 - val_loss: 1.0173 - val_accuracy: 0.4693
# Epoch 9/10
# 9/9 [==============================] - 5s 528ms/step - loss: 0.5692 - accuracy: 0.7593 - val_loss: 0.7770 - val_accuracy: 0.5659
# Epoch 10/10
# 9/9 [==============================] - 5s 523ms/step - loss: 0.5247 - accuracy: 0.7734 - val_loss: 0.9931 - val_accuracy: 0.5352
# 11/11 [==============================] - 0s 33ms/step - loss: 1.7054 - accuracy: 0.2621
# Score : loss of 1.70538330078125; accuracy of 26.210826635360718%
# 11/11 [==============================] - 0s 21ms/step
# F1 score :  0.3684902612236356
# Confusion Matrix :
# [[ 82 190  14   0]
#  [  2   8  35   0]
#  [  4  14   2   0]
#  [  0   0   0   0]]
# Accuracy with participant p09 as test :26.210826635360718
# ====================================================================================
#
#
# Training with participant p10 left out
# (2990, 1800, 5) (2990,)
# (2990,)
# Epoch 1/10
# 9/9 [==============================] - 6s 577ms/step - loss: 0.8675 - accuracy: 0.6111 - val_loss: 1.1406 - val_accuracy: 0.3512
# Epoch 2/10
# 9/9 [==============================] - 5s 534ms/step - loss: 0.6628 - accuracy: 0.7348 - val_loss: 1.0018 - val_accuracy: 0.6031
# Epoch 3/10
# 9/9 [==============================] - 5s 553ms/step - loss: 0.6102 - accuracy: 0.7726 - val_loss: 0.6317 - val_accuracy: 0.6421
# Epoch 4/10
# 9/9 [==============================] - 5s 541ms/step - loss: 0.5671 - accuracy: 0.7802 - val_loss: 0.7308 - val_accuracy: 0.6243
# Epoch 5/10
# 9/9 [==============================] - 5s 538ms/step - loss: 0.5278 - accuracy: 0.7817 - val_loss: 0.7149 - val_accuracy: 0.6165
# Epoch 6/10
# 9/9 [==============================] - 5s 547ms/step - loss: 0.4864 - accuracy: 0.8017 - val_loss: 0.7436 - val_accuracy: 0.6321
# Epoch 7/10
# 9/9 [==============================] - 5s 543ms/step - loss: 0.4574 - accuracy: 0.8251 - val_loss: 0.6657 - val_accuracy: 0.6700
# Epoch 8/10
# 9/9 [==============================] - 5s 535ms/step - loss: 0.3857 - accuracy: 0.8600 - val_loss: 0.6685 - val_accuracy: 0.6499
# Epoch 9/10
# 9/9 [==============================] - 5s 538ms/step - loss: 0.3047 - accuracy: 0.8868 - val_loss: 0.8827 - val_accuracy: 0.6321
# Epoch 10/10
# 9/9 [==============================] - 5s 536ms/step - loss: 0.2429 - accuracy: 0.9169 - val_loss: 0.8923 - val_accuracy: 0.6109
# 10/10 [==============================] - 0s 22ms/step - loss: 1.2192 - accuracy: 0.5748
# Score : loss of 1.2191976308822632; accuracy of 57.482993602752686%
# 10/10 [==============================] - 0s 20ms/step
# F1 score :  0.5787543130942969
# Confusion Matrix :
# [[97 16 17  0]
#  [18 29 41  0]
#  [ 2 31 43  0]
#  [ 0  0  0  0]]
# Accuracy with participant p10 as test :57.482993602752686
# ====================================================================================
#
#
# Training with participant p11 left out
# (3043, 1800, 5) (3043,)
# (3043,)
# Epoch 1/10
# 9/9 [==============================] - 6s 578ms/step - loss: 1.1308 - accuracy: 0.4775 - val_loss: 0.8141 - val_accuracy: 0.6232
# Epoch 2/10
# 9/9 [==============================] - 5s 544ms/step - loss: 0.7071 - accuracy: 0.7216 - val_loss: 0.6821 - val_accuracy: 0.6177
# Epoch 3/10
# 9/9 [==============================] - 5s 557ms/step - loss: 0.6574 - accuracy: 0.7263 - val_loss: 0.5830 - val_accuracy: 0.6758
# Epoch 4/10
# 9/9 [==============================] - 5s 544ms/step - loss: 0.6426 - accuracy: 0.7202 - val_loss: 0.7009 - val_accuracy: 0.5805
# Epoch 5/10
# 9/9 [==============================] - 5s 561ms/step - loss: 0.6305 - accuracy: 0.7235 - val_loss: 0.6789 - val_accuracy: 0.5991
# Epoch 6/10
# 9/9 [==============================] - 5s 542ms/step - loss: 0.6073 - accuracy: 0.7512 - val_loss: 0.7889 - val_accuracy: 0.5531
# Epoch 7/10
# 9/9 [==============================] - 5s 545ms/step - loss: 0.5789 - accuracy: 0.7554 - val_loss: 0.6884 - val_accuracy: 0.5991
# Epoch 8/10
# 9/9 [==============================] - 5s 550ms/step - loss: 0.5475 - accuracy: 0.7770 - val_loss: 0.7357 - val_accuracy: 0.6090
# Epoch 9/10
# 9/9 [==============================] - 5s 549ms/step - loss: 0.5022 - accuracy: 0.8005 - val_loss: 0.7523 - val_accuracy: 0.6210
# Epoch 10/10
# 9/9 [==============================] - 5s 544ms/step - loss: 0.4666 - accuracy: 0.8056 - val_loss: 0.7209 - val_accuracy: 0.6298
# 8/8 [==============================] - 0s 22ms/step - loss: 2.1463 - accuracy: 0.3610
# Score : loss of 2.1463255882263184; accuracy of 36.09958589076996%
# 8/8 [==============================] - 0s 21ms/step
# F1 score :  0.40947137099162534
# Confusion Matrix :
# [[13  0  0  0]
#  [27 17  7  0]
#  [23 97 57  0]
#  [ 0  0  0  0]]
# Accuracy with participant p11 as test :36.09958589076996
# ====================================================================================
#
#
# Training with participant p12 left out
# (2914, 1800, 5) (2914,)
# (2914,)
# Epoch 1/10
# 8/8 [==============================] - 6s 617ms/step - loss: 1.1177 - accuracy: 0.4743 - val_loss: 0.6757 - val_accuracy: 0.7669
# Epoch 2/10
# 8/8 [==============================] - 5s 583ms/step - loss: 0.6942 - accuracy: 0.7254 - val_loss: 0.6311 - val_accuracy: 0.7017
# Epoch 3/10
# 8/8 [==============================] - 5s 601ms/step - loss: 0.6746 - accuracy: 0.7425 - val_loss: 0.6477 - val_accuracy: 0.7006
# Epoch 4/10
# 8/8 [==============================] - 5s 601ms/step - loss: 0.6444 - accuracy: 0.7425 - val_loss: 0.6569 - val_accuracy: 0.6949
# Epoch 5/10
# 8/8 [==============================] - 5s 591ms/step - loss: 0.6215 - accuracy: 0.7450 - val_loss: 0.6947 - val_accuracy: 0.6857
# Epoch 6/10
# 8/8 [==============================] - 5s 603ms/step - loss: 0.6080 - accuracy: 0.7494 - val_loss: 0.6627 - val_accuracy: 0.6926
# Epoch 7/10
# 8/8 [==============================] - 5s 592ms/step - loss: 0.5844 - accuracy: 0.7558 - val_loss: 0.6813 - val_accuracy: 0.6686
# Epoch 8/10
# 8/8 [==============================] - 5s 592ms/step - loss: 0.5664 - accuracy: 0.7641 - val_loss: 0.6866 - val_accuracy: 0.6594
# Epoch 9/10
# 8/8 [==============================] - 5s 684ms/step - loss: 0.5390 - accuracy: 0.7690 - val_loss: 0.7291 - val_accuracy: 0.6206
# Epoch 10/10
# 8/8 [==============================] - 5s 608ms/step - loss: 0.5025 - accuracy: 0.7906 - val_loss: 0.7743 - val_accuracy: 0.5931
# 12/12 [==============================] - 0s 31ms/step - loss: 0.9287 - accuracy: 0.5297
# Score : loss of 0.9287107586860657; accuracy of 52.97297239303589%
# 12/12 [==============================] - 0s 26ms/step
# F1 score :  0.5804998488542793
# Confusion Matrix :
# [[ 89 166   5   0]
#  [  2  31   0   0]
#  [  0   1  76   0]
#  [  0   0   0   0]]
# Accuracy with participant p12 as test :52.97297239303589
# ====================================================================================
#
#
# Training with participant p13 left out
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/jai/Documents/IEEE-Interest/interest/analysis/code/ipynb/gaze-analysis_CNN.ipynb Cell 10 in <cell line: 6>()
#       <a href='vscode-notebook-cell:/Users/jai/Documents/IEEE-Interest/interest/analysis/code/ipynb/gaze-analysis_CNN.ipynb#X11sZmlsZQ%3D%3D?line=8'>9</a> label = []
#      <a href='vscode-notebook-cell:/Users/jai/Documents/IEEE-Interest/interest/analysis/code/ipynb/gaze-analysis_CNN.ipynb#X11sZmlsZQ%3D%3D?line=9'>10</a> print("Training with participant "+ participants[i] +" left out")
# ---> <a href='vscode-notebook-cell:/Users/jai/Documents/IEEE-Interest/interest/analysis/code/ipynb/gaze-analysis_CNN.ipynb#X11sZmlsZQ%3D%3D?line=10'>11</a> num_time_periods, num_sensors, t_x, val_x, t_y, val_y = prepare_data(gaze_data, i)
#      <a href='vscode-notebook-cell:/Users/jai/Documents/IEEE-Interest/interest/analysis/code/ipynb/gaze-analysis_CNN.ipynb#X11sZmlsZQ%3D%3D?line=11'>12</a> results, scores, preds, acc, f1 = evaluate(num_time_periods, num_sensors,t_x, val_x, t_y, val_y, EPOCHS, BATCH_SIZE)
#      <a href='vscode-notebook-cell:/Users/jai/Documents/IEEE-Interest/interest/analysis/code/ipynb/gaze-analysis_CNN.ipynb#X11sZmlsZQ%3D%3D?line=12'>13</a> model_history.append(results)
#
# /Users/jai/Documents/IEEE-Interest/interest/analysis/code/ipynb/gaze-analysis_CNN.ipynb Cell 10 in prepare_data(data, fold)
#       <a href='vscode-notebook-cell:/Users/jai/Documents/IEEE-Interest/interest/analysis/code/ipynb/gaze-analysis_CNN.ipynb#X11sZmlsZQ%3D%3D?line=4'>5</a> def prepare_data(data, fold):
#       <a href='vscode-notebook-cell:/Users/jai/Documents/IEEE-Interest/interest/analysis/code/ipynb/gaze-analysis_CNN.ipynb#X11sZmlsZQ%3D%3D?line=6'>7</a>     df_val = data[data['participant'] == participants[fold]]
# ----> <a href='vscode-notebook-cell:/Users/jai/Documents/IEEE-Interest/interest/analysis/code/ipynb/gaze-analysis_CNN.ipynb#X11sZmlsZQ%3D%3D?line=7'>8</a>     df_train = data[data['participant'] != participants[fold]]
#      <a href='vscode-notebook-cell:/Users/jai/Documents/IEEE-Interest/interest/analysis/code/ipynb/gaze-analysis_CNN.ipynb#X11sZmlsZQ%3D%3D?line=9'>10</a>     # df_train.drop(['participant','document'], axis=1, inplace=True)
#      <a href='vscode-notebook-cell:/Users/jai/Documents/IEEE-Interest/interest/analysis/code/ipynb/gaze-analysis_CNN.ipynb#X11sZmlsZQ%3D%3D?line=10'>11</a>     # df_val.drop(['participant','document'], axis=1, inplace=True)
#      <a href='vscode-notebook-cell:/Users/jai/Documents/IEEE-Interest/interest/analysis/code/ipynb/gaze-analysis_CNN.ipynb#X11sZmlsZQ%3D%3D?line=12'>13</a>     df_train = df_train[features]
#
# File ~/miniconda3/envs/dl/lib/python3.10/site-packages/pandas/core/ops/common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File ~/miniconda3/envs/dl/lib/python3.10/site-packages/pandas/core/arraylike.py:44, in OpsMixin.__ne__(self, other)
#      42 @unpack_zerodim_and_defer("__ne__")
#      43 def __ne__(self, other):
# ---> 44     return self._cmp_method(other, operator.ne)
#
# File ~/miniconda3/envs/dl/lib/python3.10/site-packages/pandas/core/series.py:5623, in Series._cmp_method(self, other, op)
#    5620 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    5622 with np.errstate(all="ignore"):
# -> 5623     res_values = ops.comparison_op(lvalues, rvalues, op)
#    5625 return self._construct_result(res_values, name=res_name)
#
# File ~/miniconda3/envs/dl/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:283, in comparison_op(left, right, op)
#     280     return invalid_comparison(lvalues, rvalues, op)
#     282 elif is_object_dtype(lvalues.dtype) or isinstance(rvalues, str):
# --> 283     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     285 else:
#     286     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File ~/miniconda3/envs/dl/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:73, in comp_method_OBJECT_ARRAY(op, x, y)
#      71     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      72 else:
# ---> 73     result = libops.scalar_compare(x.ravel(), y, op)
#      74 return result.reshape(x.shape)
#
# KeyboardInterrupt:

# %%
print (np.mean(acc), np.mean(f1))
